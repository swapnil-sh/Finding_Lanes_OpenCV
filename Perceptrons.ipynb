# %% [markdown]
# ## Perceptrons
#
# Perceptrons are the most basic foprms of neural networks that takes inspiration from the brain. Like a brain a perceptron is a basic processing element that also receives input processes it and generates an output based on the predictive model.
#
# Below we have node which contains already classifed data.
# Our model node is going to receive two input nodes age(x1) and blood sugar level(x2)

# %%
from IPython.display import Image
#Image(filename='node_perceptron.png') 
Image(filename='node_with_ip_op.png')

# %% [markdown]
# ## Activation Function
#
# In neural netwroks the activation function of a node is what defines the output.
# The most common type of activation function that we are using all along subconsiously is the step function
#
# It is the step function that checks the result of our linear combination. If its positive the point is below the line and therefore we assign a label of 1 otherwise if it is less than 0 the point is above the line and value assigned is 0.

# %%
Image(filename='activation_function.png')
